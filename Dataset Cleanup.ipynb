# %%
# Dependencies
import pandas as pd
import numpy as np

# %%
# Save file patth to variable
retail_history_csv = "Datasets/EstUS_Retail_Trade_E-commercehistory.csv"

# %%
retail_history_df = pd.read_csv(retail_history_csv)
retail_history_df.head()
# Out:
#   Table with row headers in column B and NAICS codes in column A with column headers in rows 4 and 5  \
# 0  Estimated Annual U.S. Retail Trade Sales - Tot...
# 1  [Estimates are shown in millions of dollars an...
# 2                                         NAICS Code
# 3                                                NaN
# 4                                                NaN
#
#                                       Unnamed: 1 Unnamed: 2  Unnamed: 3  \
# 0                                            NaN        NaN         NaN
# 1                                            NaN        NaN         NaN
# 2                                            NaN       2018         NaN
# 3                              Kind of Business       Total  E-commerce
# 4  Total Retail Trade ………………………...……………………………………  5,269,468     519,635
#
#   Unnamed: 4  Unnamed: 5 Unnamed: 6  Unnamed: 7 Unnamed: 8  Unnamed: 9  ...  \
# 0        NaN         NaN        NaN         NaN        NaN         NaN  ...
# 1        NaN         NaN        NaN         NaN        NaN         NaN  ...
# 2      2017r         NaN      2016r         NaN      2015r         NaN  ...
# 3      Total  E-commerce      Total  E-commerce      Total  E-commerce  ...
# 4  5,053,151     458,916  4,852,958     397,252  4,725,993     346,188  ...
#
#   Unnamed: 34 Unnamed: 35 Unnamed: 36 Unnamed: 37 Unnamed: 38 Unnamed: 39  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2        2002         NaN        2001         NaN        2000         NaN
# 3       Total  E-commerce       Total  E-commerce       Total  E-commerce
# 4   3,128,552      44,623   3,062,268      34,260   2,983,276      27,608
#
#   Unnamed: 40 Unnamed: 41 Unnamed: 42 Unnamed: 43
# 0         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN
# 2        1999         NaN        1998         NaN
# 3       Total  E-commerce       Total  E-commerce
# 4   2,803,090      14,490   2,581,762       4,984
#
# [5 rows x 44 columns]
