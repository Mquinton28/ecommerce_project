# %%
#Dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
# Name of the CSV file
AZ_retail_csv = os.path.join('Datasets','AZ Retail Data.csv')

# %%
# creating a data frame 
AZ_df = pd.read_csv(AZ_retail_csv) 
AZ_df.head()
# Out:
#              Geo Footnote Geographic Area Name 2017 NAICS code  \
# 0400000US04           NaN              Arizona           44-45
# 0400000US04           NaN              Arizona             441
# 0400000US04           NaN              Arizona             442
# 0400000US04           NaN              Arizona             443
# 0400000US04           NaN              Arizona             444
#
#              2017 NAICS Footnote  \
# 0400000US04                  NaN
# 0400000US04                  NaN
# 0400000US04                  NaN
# 0400000US04                  NaN
# 0400000US04                  NaN
#
#                                          Meaning of NAICS code  Year  \
# 0400000US04                                       Retail trade  2017
# 0400000US04                    Motor vehicle and parts dealers  2017
# 0400000US04              Furniture and home furnishings stores  2017
# 0400000US04                   Electronics and appliance stores  2017
# 0400000US04  Building material and garden equipment and sup...  2017
#
#             Number of firms Number of establishments  \
# 0400000US04            9830                    17918
# 0400000US04            1250                     2059
# 0400000US04             621                      959
# 0400000US04             304                      524
# 0400000US04             708                     1087
#
#             Sales, value of shipments, or revenue ($1,000)  \
# 0400000US04                                      104365600
# 0400000US04                                       25808220
# 0400000US04                                        2436003
# 0400000US04                                        1798437
# 0400000US04                                        5569365
#
#             Annual payroll ($1,000) First-quarter payroll ($1,000)  \
# 0400000US04                 9505481                        2365502
# 0400000US04                 2192296                         534080
# 0400000US04                  310635                          75007
# 0400000US04                  211244                          47338
# 0400000US04                  638354                         157251
#
#             Number of employees  \
# 0400000US04              324912
# 0400000US04               44267
# 0400000US04                9962
# 0400000US04                6436
# 0400000US04               23621
#
#             Range indicating percent of total sales, value of shipments, or revenue imputed  \
# 0400000US04                                      Less than 10%
# 0400000US04                                      Less than 10%
# 0400000US04                               10% to less than 20%
# 0400000US04                                      Less than 10%
# 0400000US04                                      Less than 10%
#
#             Range indicating percent of total annual payroll imputed  \
# 0400000US04                               10% to less than 20%
# 0400000US04                               10% to less than 20%
# 0400000US04                               10% to less than 20%
# 0400000US04                               30% to less than 40%
# 0400000US04                                      Less than 10%
#
#             Range indicating percent of total employees imputed
# 0400000US04                               10% to less than 20%
# 0400000US04                               10% to less than 20%
# 0400000US04                               30% to less than 40%
# 0400000US04                               20% to less than 30%
# 0400000US04                                      Less than 10%

# %%
# Delete extraneous column
AZ_df = AZ_df.drop(columns=['Geo Footnote', '2017 NAICS Footnote', 'id', '2017 NAICS code', 
                            'Annual payroll ($1,000)', 'First-quarter payroll ($1,000)', 
                            'Number of employees', 'Range indicating percent of total annual payroll imputed', 
                            'Range indicating percent of total employees imputed', 
                           ])


AZ_df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-9f82d2cd59bc> in <module>
#       3                             'Annual payroll ($1,000)', 'First-quarter payroll ($1,000)',
#       4                             'Number of employees', 'Range indicating percent of total annual payroll imputed',
# ----> 5                             'Range indicating percent of total employees imputed',
#       6                            ])
#       7
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    3968                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3969             else:
# -> 3970                 new_axis = axis.drop(labels, errors=errors)
#    3971             result = self.reindex(**{axis_name: new_axis})
#    3972
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    5016         if mask.any():
#    5017             if errors != "ignore":
# -> 5018                 raise KeyError(f"{labels[mask]} not found in axis")
#    5019             indexer = indexer[~mask]
#    5020         return self.delete(indexer)
#
# KeyError: "['id'] not found in axis"

# %%
AZ_df.loc[AZ_df['Meaning of NAICS code']=='Electronic shopping and mail-order houses', 'eCommerce?']= 1
AZ_df.loc[AZ_df['Meaning of NAICS code']!='Electronic shopping and mail-order houses', 'eCommerce?']= 0

AZ_df.head()

# %%
AZ_df.groupby('eCommerce?')['Sales, value of shipments, or revenue ($1,000)'].sum()

# %%
#Create Pie Chart
labels = "eCommerce", "Retail"
value = [257001507, 2717305378]
colors = ["purple", "grey"]
explode = (0.3,0)

# %%
# Create a pie chart based upon the above data
plt.pie(value, labels=labels, colors=colors, explode=explode,
        autopct="%1.1f%%", shadow=True, startangle=180)
plt.title("eCommerce vs Retail 2017")

# Create axes which are equal so we have a perfect circle
plt.axis("equal")
plt.show()
#plt.savefig("../Images/PyPies.png")

# %%
#Number of Establishments

# %%
AZ_df.loc[AZ_df['Meaning of NAICS code']=='Electronic shopping and mail-order houses', 'eCommerce?']= 1
AZ_df.loc[AZ_df['Meaning of NAICS code']!='Electronic shopping and mail-order houses', 'eCommerce?']= 0

AZ_df.head()

# %%
AZ_df.groupby('eCommerce?')['Number of establishments'].sum()
